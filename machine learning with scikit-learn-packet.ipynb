# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # traning data
#         cross validation is used when training data is  scarce
#    ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # bias and variance
# ## performance metrics
# * can be used to measure the prediction error
# * causes of prediction error-bias and variance
# ![image.png](attachment:image.png)
#
#
# ## performance metrics for unsupervised learning
# * no error signal
# * measure attribute of the structure in data
#
# ## performance metrics
# * can be caluculated for a specific task
# * systems should be evaluated using real world associated measures
#
# ## the libariry
#         pandas\nltk\pillow\matplotlib

# %% [markdown]
# ![image.png](attachment:image.png)
# * accuracy=(TP+TN)/(TP+TN+FP+FN)
# * precision=TP/(TP+FP)
# * recall=TP/(TP+FN)

# %% [markdown]
# # the perceptron
#         1. basic understanding of a perceptron
#         2. different activation functions
#         3. perceptron learning algnorithm
#         4. performing document classification with scikit-learn
# # online learning
#         1. learning algorithm can update model's parameters using:
#             * single training instance rather than the entire batch
#         2. useful for learning from training sets too large to represent in memory

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # preactivation
#       the linear combination of the parameters and inputs is sometimes called preactivation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # documet classification
#         methods used:1、fit 2、predict 3、partial_fit-allows classifier to be trained incrementally

# %%
# perceptron
# documents classification with the perceptron

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Perceptron
from sklearn.metrics import f1_score,classification_report

categories=['rec.sport.hockey','rec.sport.baseball','rec.autos']
newsgroups_train=fetch_20newsgroups(subset='train',categories=categories,remove=('headers','footers','quotes'))
newsgroups_test=fetch_20newsgroups(subset='test',categories=categories,remove=('headers','footers','quotes'))
vectorizer=TfidfVectorizer()
X_train=vectorizer.fit_transform(newsgroups_train.data)
X_test=vectorizer.transform(newsgroups_test.data)
clf=Perceptron(random_state=11)
clf.fit(X_train,newsgroups_train.target)
predictions=clf.predict(X_test)
print(classification_report(newsgroups_test.target,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.92      0.86       396
#           1       0.87      0.76      0.81       397
#           2       0.86      0.85      0.86       399
#
# avg / total       0.85      0.84      0.84      1192
# /Users/four/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %% [markdown]
# # from the perceptron to support vector machines
# ## kenels and the kernel trick
#     a kernel is a function that,given the original feature vectors,returns the same value as the dot product of its
#     corresponding mapped feature vectors
#     1. do not explicitly map feature vectors to a higher dimensinonal space
#     2. do not calculate the dot product of the mapped vectors
#     3. produce the same value through a different series of operations
#     4. that can often be computed more efficiently
#
#     在机器学习中常用的核函数，一般有这么几类，也就是LibSVM中自带的这几类：
#         1) 线性：K(v1,v2)=<v1,v2>
#         2) 多项式：K(v1,v2)=(γ<v1,v2>+c)n
#         3) Radial basis function：K(v1,v2)=exp(−γ||v1−v2||2)
#         4) Sigmoid：K(v1,v2)=tanh(γ<v1,v2>+c)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# maximum margin classification and support vectors
